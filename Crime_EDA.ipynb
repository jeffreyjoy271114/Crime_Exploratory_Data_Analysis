# %%
# Import the required Libraries

# Importing Libraries for Data Manipulation and Data Wrangling
import pandas as pd
import numpy as np
from encodings.aliases import aliases #Python has a file containing a dictionary of encoding names and associated aliases

# Importing Libraries for Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Reading the Data 
crime = pd.read_csv('crime.csv')
crime

# This code will not work as there is a utf-87 encoding error
# So to resolve this we will be using the library callled the encoding.aliases
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4104\3536008481.py in <module>
#       1 # Reading the Data
# ----> 2 crime = pd.read_csv('crime.csv')
#       3 crime
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# To find the encodings that willl work 

# Below lines creates a set of all available encodings
alias_values = set(aliases.values())

for encoding in set(aliases.values()):
    try:
        crime = pd.read_csv('crime.csv', nrows=10, encoding=encoding) # Will read in only 10 LOC for faster read
        print('Successful', encoding)
    except:
        pass
# Out:
# Successful cp1125
# Successful iso8859_10
# Successful iso8859_4
# Successful cp862
# Successful mac_iceland
# Successful cp1250
# Successful mac_greek
# Successful iso8859_15
# Successful ptcp154
# Successful cp775
# Successful cp273
# Successful cp864
# Successful cp932
# Successful cp852
# Successful gbk
# Successful mac_roman
# Successful cp861
# Successful cp858
# Successful cp1253
# Successful cp1255
# Successful iso8859_9
# Successful iso8859_14
# Successful utf_16_le
# Successful hp_roman8
# Successful iso8859_13
# Successful cp855
# Successful iso8859_5
# Successful gb18030
# Successful cp037
# Successful cp1140
# Successful iso8859_6
# Successful cp865
# Successful cp1251
# Successful cp869
# Successful mac_turkish
# Successful koi8_r
# Successful cp949
# Successful cp850
# Successful mac_latin2
# Successful cp860
# Successful cp1256
# Successful iso8859_2
# Successful mac_cyrillic
# Successful cp863
# Successful iso8859_16
# Successful cp1026
# Successful cp1254
# ...

# %%
# Using the encoding style from the above list
crime = pd.read_csv('crime.csv', encoding='iso8859_10')
crime
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                        LARCENY ALL OTHERS      D14            808      NaN
# 1                                 VANDALISM      C11            347      NaN
# ...

# %%
crime.info() # Checking the Data Types and also if there are any null values or not of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319073 entries, 0 to 319072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      319073 non-null  object
#  1   OFFENSE_CODE         319073 non-null  int64
#  2   OFFENSE_CODE_GROUP   319073 non-null  object
#  3   OFFENSE_DESCRIPTION  319073 non-null  object
#  4   DISTRICT             317308 non-null  object
#  5   REPORTING_AREA       319073 non-null  object
#  6   SHOOTING             1019 non-null    object
#  7   OCCURRED_ON_DATE     319073 non-null  object
#  8   YEAR                 319073 non-null  int64
#  9   MONTH                319073 non-null  int64
#  10  DAY_OF_WEEK          319073 non-null  object
#  11  HOUR                 319073 non-null  int64
#  12  UCR_PART             318983 non-null  object
#  13  STREET               308202 non-null  object
#  14  Lat                  299074 non-null  float64
# ...

# %%
crime.shape # Checking the shape of the data. It has 319073 Rows and 17 columns
# Out:
# (319073, 17)

# %%
crime.duplicated().sum() # Checking and counting the duplicated rows
# Out:
# 23

# %%
crime.drop_duplicates(inplace=True) # Dropping the dupicated rows

# %%
crime.shape # Checking if the drop has worked properly or not
# Out:
# (319050, 17)

# %%
crime.isnull().sum() # Another way of checking if there are any null values or not
# Out:
# INCIDENT_NUMBER             0
# OFFENSE_CODE                0
# OFFENSE_CODE_GROUP          0
# OFFENSE_DESCRIPTION         0
# DISTRICT                 1765
# REPORTING_AREA              0
# SHOOTING               318031
# OCCURRED_ON_DATE            0
# YEAR                        0
# MONTH                       0
# DAY_OF_WEEK                 0
# HOUR                        0
# UCR_PART                   90
# STREET                  10871
# Lat                     19998
# Long                    19998
# Location                    0
# dtype: int64

# %%
crime.columns # command to get the column names
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
# Changing the data type from object to datetime for occured_on_date column
crime.OCCURRED_ON_DATE = pd.to_datetime(crime.OCCURRED_ON_DATE)

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319050 entries, 0 to 319072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      319050 non-null  object
#  1   OFFENSE_CODE         319050 non-null  int64
#  2   OFFENSE_CODE_GROUP   319050 non-null  object
#  3   OFFENSE_DESCRIPTION  319050 non-null  object
#  4   DISTRICT             317285 non-null  object
#  5   REPORTING_AREA       319050 non-null  object
#  6   SHOOTING             1019 non-null    object
#  7   OCCURRED_ON_DATE     319050 non-null  datetime64[ns]
#  8   YEAR                 319050 non-null  int64
#  9   MONTH                319050 non-null  int64
#  10  DAY_OF_WEEK          319050 non-null  object
#  11  HOUR                 319050 non-null  int64
#  12  UCR_PART             318960 non-null  object
#  13  STREET               308179 non-null  object
# ...

# %%
# Getting the summary information of the crime dataset
crime.describe()
# Out:
#         OFFENSE_CODE           YEAR          MONTH           HOUR  \
# count  319050.000000  319050.000000  319050.000000  319050.000000
# mean     2317.516957    2016.560674       6.609622      13.118176
# std      1185.308921       0.996312       3.273677       6.294258
# min       111.000000    2015.000000       1.000000       0.000000
# 25%      1001.000000    2016.000000       4.000000       9.000000
# 50%      2907.000000    2017.000000       7.000000      14.000000
# 75%      3201.000000    2017.000000       9.000000      18.000000
# max      3831.000000    2018.000000      12.000000      23.000000
#
#                  Lat           Long
# count  299052.000000  299052.000000
# mean       42.214373     -70.908260
# std         2.159845       3.493746
# min        -1.000000     -71.178674
# 25%        42.297438     -71.097135
# 50%        42.325538     -71.077524
# 75%        42.348624     -71.062467
# max        42.395042      -1.000000

# %%
# Will give the summary Information of the data where the column is object
crime.describe(include = 'object')
# Out:
#        INCIDENT_NUMBER               OFFENSE_CODE_GROUP  \
# count           319050                           319050
# unique          282517                               67
# top         I162030584  Motor Vehicle Accident Response
# freq                13                            37132
#
#                   OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# count                          319050   317285         319050     1019
# unique                            244       12            879        1
# top     SICK/INJURED/MEDICAL - PERSON       B2                       Y
# freq                            18783    49940          20250     1019
#
#        DAY_OF_WEEK    UCR_PART         STREET                  Location
# count       319050      318960         308179                    319050
# unique           7           4           4657                     18194
# top         Friday  Part Three  WASHINGTON ST  (0.00000000, 0.00000000)
# ...

# %%
# Will give the summary information of all the data
crime.describe(include = 'all')
# Out:
# C:\Users\Jeffrey\AppData\Local\Temp\ipykernel_4104\3620946568.py:2: FutureWarning:
#
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#        INCIDENT_NUMBER   OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# count           319050  319050.000000                           319050
# unique          282517            NaN                               67
# top         I162030584            NaN  Motor Vehicle Accident Response
# freq                13            NaN                            37132
# first              NaN            NaN                              NaN
# last               NaN            NaN                              NaN
# mean               NaN    2317.516957                              NaN
# std                NaN    1185.308921                              NaN
# ...

# %% [markdown]
# ## Answer some of the questions

# %% [markdown]
# ### 1.What are the most common crimes in terms of offence groups?

# %%
# Getting the counts of each offense code group
crime.OFFENSE_CODE_GROUP.value_counts()
# Out:
# Motor Vehicle Accident Response              37132
# Larceny                                      25935
# Medical Assistance                           23540
# Investigate Person                           18749
# Other                                        18073
#                                              ...
# HUMAN TRAFFICKING                                7
# INVESTIGATE PERSON                               4
# Biological Threat                                2
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE        2
# Burglary - No Property Taken                     2
# Name: OFFENSE_CODE_GROUP, Length: 67, dtype: int64

# %%
# Creating the percentage dataframe of the top 10 offense group

offense_group_vals = crime.OFFENSE_CODE_GROUP.value_counts()[:10]

display(offense_group_vals / crime.shape[0])

# Creating a bar plot of thr top 10 offence groups
(offense_group_vals / crime.shape[0]).plot(kind = 'bar');
plt.title("Top 10 Offense Group in Percentage(%) of all crimes")
# Out:
# Motor Vehicle Accident Response    0.116383
# Larceny                            0.081288
# Medical Assistance                 0.073782
# Investigate Person                 0.058765
# Other                              0.056646
# Drug Violation                     0.051857
# Simple Assault                     0.049604
# Vandalism                          0.048312
# Verbal Disputes                    0.041056
# Towed                              0.035377
# Name: OFFENSE_CODE_GROUP, dtype: float64
# Text(0.5, 1.0, 'Top 10 Offense Group in Percentage(%) of all crimes')

# %% [markdown]
# ### 2. What are the Least common Offense groups?

# %%
crime.OFFENSE_CODE_GROUP.value_counts()
# Out:
# Motor Vehicle Accident Response              37132
# Larceny                                      25935
# Medical Assistance                           23540
# Investigate Person                           18749
# Other                                        18073
#                                              ...
# HUMAN TRAFFICKING                                7
# INVESTIGATE PERSON                               4
# Biological Threat                                2
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE        2
# Burglary - No Property Taken                     2
# Name: OFFENSE_CODE_GROUP, Length: 67, dtype: int64

# %%
# Creating the bottom or the least 10 offense group dataframe  

offense_group_vals = crime.OFFENSE_CODE_GROUP.value_counts(ascending=True)[:10]

display(offense_group_vals / crime.shape[0])

# Creating a bar plot of thr top 10 offence groups
(offense_group_vals / crime.shape[0]).plot(kind = 'bar');
plt.title("Bottom or Least 10 Offense Group in Percentage(%) of all crimes")
# Out:
# Burglary - No Property Taken                 0.000006
# Biological Threat                            0.000006
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE    0.000006
# INVESTIGATE PERSON                           0.000013
# HUMAN TRAFFICKING                            0.000022
# Gambling                                     0.000025
# Manslaughter                                 0.000025
# Explosives                                   0.000085
# Phone Call Complaints                        0.000097
# Aircraft                                     0.000113
# Name: OFFENSE_CODE_GROUP, dtype: float64
# Text(0.5, 1.0, 'Bottom or Least 10 Offense Group in Percentage(%) of all crimes')

# %% [markdown]
# ### 3. What are the most common offense description?

# %%
crime.OFFENSE_DESCRIPTION.value_counts()
# Out:
# SICK/INJURED/MEDICAL - PERSON                  18783
# INVESTIGATE PERSON                             18753
# M/V - LEAVING SCENE - PROPERTY DAMAGE          16323
# VANDALISM                                      15153
# ASSAULT SIMPLE - BATTERY                       14791
#                                                ...
# KILLING OF FELON BY POLICE                         1
# AUTO THEFT - OUTSIDE - RECOVERED IN BOSTON         1
# DRUGS - GLUE INHALATION                            1
# ROBBERY - KNIFE - STREET                           1
# DRUGS - POSS CLASS D - INTENT MFR DIST DISP        1
# Name: OFFENSE_DESCRIPTION, Length: 244, dtype: int64

# %%
# Creating the top 10 most offense description dataframe

offense_des_group_vals = crime.OFFENSE_DESCRIPTION.value_counts()[:10]

display(offense_des_group_vals / crime.shape[0])

# Creating a bar plt of the 10 most offense description in terms of percentage
(offense_des_group_vals / crime.shape[0]).plot(kind = 'bar');
plt.title("Top 10 Offense Description in Percentage(%) of all crimes")
# Out:
# SICK/INJURED/MEDICAL - PERSON            0.058872
# INVESTIGATE PERSON                       0.058778
# M/V - LEAVING SCENE - PROPERTY DAMAGE    0.051161
# VANDALISM                                0.047494
# ASSAULT SIMPLE - BATTERY                 0.046360
# VERBAL DISPUTE                           0.041056
# TOWED MOTOR VEHICLE                      0.035377
# INVESTIGATE PROPERTY                     0.034866
# LARCENY THEFT FROM BUILDING              0.028425
# THREATS TO DO BODILY HARM                0.028340
# Name: OFFENSE_DESCRIPTION, dtype: float64
# Text(0.5, 1.0, 'Top 10 Offense Description in Percentage(%) of all crimes')

# %% [markdown]
# ### 4. What is the bottom or the Least offense description ?

# %%
# Creating the bottom or the least 10 offense description dataframe

offense_des_group_vals = crime.OFFENSE_DESCRIPTION.value_counts(ascending=True)[:10]

display(offense_des_group_vals / crime.shape[0])

# Creating a bar plt of the 10 most offense description in terms of percentage
(offense_des_group_vals / crime.shape[0]).plot(kind = 'bar');
plt.title("Top 10 Offense Description in Percentage(%) of all crimes")
# Out:
# DRUGS - POSS CLASS D - INTENT MFR DIST DISP    0.000003
# LARCENY IN A BUILDING $50 TO $199              0.000003
# ROBBERY - UNARMED - CHAIN STORE                0.000003
# VIOLATION - RESTRAINING ORDER                  0.000003
# AUTO THEFT LEASE/RENT VEHICLE                  0.000003
# FRAUD - FALSE PRETENSE                         0.000003
# ASSAULT D/W - KNIFE ON POLICE OFFICER          0.000003
# ROBBERY ATTEMPT - KNIFE - BANK                 0.000003
# ASSAULT D/W - OTHER                            0.000003
# AUTO THEFT - OUTSIDE - RECOVERED IN BOSTON     0.000003
# Name: OFFENSE_DESCRIPTION, dtype: float64
# Text(0.5, 1.0, 'Top 10 Offense Description in Percentage(%) of all crimes')

# %% [markdown]
# ### 5. In Which Year were the most crime commited?

# %%
# Using the groupby function to group the year and the incident number to get the most crimes commited in each year

crime.groupby('YEAR').count()['INCIDENT_NUMBER'].sort_values().plot(kind = 'bar')
plt.title("Number Of Crimes")
# Out:
# Text(0.5, 1.0, 'Number Of Crimes')

# %% [markdown]
# ### 6. Are there more crimes committed on specific days?

# %%
crime.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
crime.groupby('DAY_OF_WEEK').count()
# Out:
#              INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# DAY_OF_WEEK
# Friday                 48489         48489               48489
# Monday                 45674         45674               45674
# Saturday               44816         44816               44816
# Sunday                 40313         40313               40313
# Thursday               46655         46655               46655
# Tuesday                46376         46376               46376
# Wednesday              46727         46727               46727
#
#              OFFENSE_DESCRIPTION  DISTRICT  REPORTING_AREA  SHOOTING  \
# DAY_OF_WEEK
# Friday                     48489     48190           48489       143
# Monday                     45674     45417           45674       114
# Saturday                   44816     44580           44816       228
# Sunday                     40313     40094           40313       155
# Thursday                   46655     46385           46655       131
# ...

# %%
crime.groupby('DAY_OF_WEEK').count()['INCIDENT_NUMBER']
# Out:
# DAY_OF_WEEK
# Friday       48489
# Monday       45674
# Saturday     44816
# Sunday       40313
# Thursday     46655
# Tuesday      46376
# Wednesday    46727
# Name: INCIDENT_NUMBER, dtype: int64

# %%
# Visualizing The Above Data

crime.groupby('DAY_OF_WEEK').count()['INCIDENT_NUMBER'].sort_values().plot(kind = 'bar')
plt.title('Crimes Commited on the Days of the Week')
# Out:
# Text(0.5, 1.0, 'Crimes Commited on the Days of the Week')

# %% [markdown]
# ### 7. Are there more crimes during Specific Hour?

# %%
# Using the Groupby function to group by hour and the incident number and using the bar plot to visualize it.

crime.groupby('HOUR').count()['INCIDENT_NUMBER'].plot(kind = 'bar')
plt.title('Crimes During Specific Hours')
# Out:
# Text(0.5, 1.0, 'Crimes During Specific Hours')

# %%
# Highest time of the Crime 
crime.groupby('HOUR').count()['INCIDENT_NUMBER'].sort_values().plot(kind = 'bar')
plt.title('Crimes During Specific Hours')
# Out:
# Text(0.5, 1.0, 'Crimes During Specific Hours')

# %% [markdown]
# ### 8. On what Days and during which hours are the most crimes commited?

# %%
# Creating a variable in which the groupby function is used to group the hour and the day of the week to get on what 
# what Days and during which hours are the most crimes commited?

week_and_hour = crime.groupby(['HOUR', 'DAY_OF_WEEK']).count()['INCIDENT_NUMBER'].unstack()

# %%
# Rearanging the columns 
week_and_hour.columns = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# Visualizing it using the heatmap via seaborn library
sns.heatmap(week_and_hour, cmap = sns.cubehelix_palette(as_cmap=True));

# %% [markdown]
# ### 9. In which months were the number of crimes below average?
# ### 10. In which months on average did the most crimes occur?

# %%
# If the Value is less than the Average we will highlight it with blue.

avg_crime = crime.groupby(['YEAR', 'MONTH']).count()['INCIDENT_NUMBER'].mean()
print(f'The Avereage number of Crimes is {avg_crime}.')

year_month = crime.groupby(['MONTH', 'YEAR']).count()['INCIDENT_NUMBER'].unstack()

def style_negative(v,props=''):
                   return props if v < avg_crime else None

s2 = year_month.style.applymap(style_negative, props='color:blue;')\
                   .applymap(lambda v:'opacity:20%;' if (v<30) and (v>-0.3) else None)
s2
# Out:
# The Avereage number of Crimes is 7976.25.
# <style type="text/css">
# #T_9c516_row0_col1, #T_9c516_row0_col3, #T_9c516_row1_col1, #T_9c516_row1_col2, #T_9c516_row1_col3, #T_9c516_row2_col3, #T_9c516_row3_col3, #T_9c516_row5_col0, #T_9c516_row8_col3, #T_9c516_row10_col0, #T_9c516_row10_col1, #T_9c516_row10_col2, #T_9c516_row11_col1, #T_9c516_row11_col2 {
#   color: blue;
# }
# </style>
# <table id="T_9c516">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_9c516_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_9c516_level0_col1" class="col_heading level0 col1" >2016</th>
#       <th id="T_9c516_level0_col2" class="col_heading level0 col2" >2017</th>
#       <th id="T_9c516_level0_col3" class="col_heading level0 col3" >2018</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MONTH</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %%
# Using the apply function to highlight the maximum in a column in darkgreen

def highlight_max(s, props = ''):
    return np.where(s == np.nanmax(s.values), props, '')
s2.apply(highlight_max, props = 'color:white; background-color:darkgreen', axis = 0)
# Out:
# <style type="text/css">
# #T_9c516_row0_col1, #T_9c516_row0_col3, #T_9c516_row1_col1, #T_9c516_row1_col2, #T_9c516_row1_col3, #T_9c516_row2_col3, #T_9c516_row3_col3, #T_9c516_row5_col0, #T_9c516_row8_col3, #T_9c516_row10_col0, #T_9c516_row10_col1, #T_9c516_row10_col2, #T_9c516_row11_col1, #T_9c516_row11_col2 {
#   color: blue;
# }
# #T_9c516_row4_col3, #T_9c516_row7_col1, #T_9c516_row7_col2, #T_9c516_row8_col0 {
#   color: white;
#   background-color: darkgreen;
# }
# </style>
# <table id="T_9c516">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_9c516_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_9c516_level0_col1" class="col_heading level0 col1" >2016</th>
#       <th id="T_9c516_level0_col2" class="col_heading level0 col2" >2017</th>
#       <th id="T_9c516_level0_col3" class="col_heading level0 col3" >2018</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MONTH</th>
# ...

# %% [markdown]
# ### 11. In which districts were the most crimes commited on yearly basis?

# %%
crime.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
crime.DISTRICT.value_counts()
# Out:
# B2     49940
# C11    42528
# D4     41914
# A1     35710
# B3     35441
# C6     23457
# D14    20127
# E13    17534
# E18    17347
# A7     13544
# E5     13238
# A15     6505
# Name: DISTRICT, dtype: int64

# %%
dist_and_year = crime.groupby(['DISTRICT', 'YEAR']).count()['INCIDENT_NUMBER'].unstack()

# We are using unstack in order to convert the data into the heatmap format

# %%
sns.heatmap(dist_and_year, cmap = sns.cubehelix_palette(as_cmap=True));

# %%
# If the Value is less than the Average we will highlight it with blue.avg_crime = crime.groupby(['DISTRICT', 'YEAR']).count()['INCIDENT_NUMBER'].mean()

print(f'The Avereage number of Crimes according to the district is {avg_crime}.')

year_month = crime.groupby(['DISTRICT', 'YEAR']).count()['INCIDENT_NUMBER'].unstack()

def style_negative(v,props=''):
                   return props if v < avg_crime else None

s2 = year_month.style.applymap(style_negative, props='color:blue;')\
                   .applymap(lambda v:'opacity:20%;' if (v<30) and (v>-0.3) else None)
s2
# Out:
# The Avereage number of Crimes according to the district is 6610.104166666667.
# <style type="text/css">
# #T_769b9_row0_col0, #T_769b9_row1_col0, #T_769b9_row1_col1, #T_769b9_row1_col2, #T_769b9_row1_col3, #T_769b9_row2_col0, #T_769b9_row2_col1, #T_769b9_row2_col2, #T_769b9_row2_col3, #T_769b9_row4_col0, #T_769b9_row6_col0, #T_769b9_row6_col3, #T_769b9_row7_col0, #T_769b9_row7_col1, #T_769b9_row7_col2, #T_769b9_row7_col3, #T_769b9_row9_col0, #T_769b9_row9_col1, #T_769b9_row9_col2, #T_769b9_row9_col3, #T_769b9_row10_col0, #T_769b9_row10_col1, #T_769b9_row10_col2, #T_769b9_row10_col3, #T_769b9_row11_col0, #T_769b9_row11_col1, #T_769b9_row11_col2, #T_769b9_row11_col3 {
#   color: blue;
# }
# </style>
# <table id="T_769b9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_769b9_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_769b9_level0_col1" class="col_heading level0 col1" >2016</th>
# ...

# %%
# Using the apply function to highlight the maximum in a column in darkgreen

def highlight_max(s, props = ''):
    return np.where(s == np.nanmax(s.values), props, '')
s2.apply(highlight_max, props = 'color:white; background-color:darkgreen', axis = 0)
# Out:
# <style type="text/css">
# #T_769b9_row0_col0, #T_769b9_row1_col0, #T_769b9_row1_col1, #T_769b9_row1_col2, #T_769b9_row1_col3, #T_769b9_row2_col0, #T_769b9_row2_col1, #T_769b9_row2_col2, #T_769b9_row2_col3, #T_769b9_row4_col0, #T_769b9_row6_col0, #T_769b9_row6_col3, #T_769b9_row7_col0, #T_769b9_row7_col1, #T_769b9_row7_col2, #T_769b9_row7_col3, #T_769b9_row9_col0, #T_769b9_row9_col1, #T_769b9_row9_col2, #T_769b9_row9_col3, #T_769b9_row10_col0, #T_769b9_row10_col1, #T_769b9_row10_col2, #T_769b9_row10_col3, #T_769b9_row11_col0, #T_769b9_row11_col1, #T_769b9_row11_col2, #T_769b9_row11_col3 {
#   color: blue;
# }
# #T_769b9_row3_col0, #T_769b9_row3_col1, #T_769b9_row3_col2, #T_769b9_row3_col3 {
#   color: white;
#   background-color: darkgreen;
# }
# </style>
# <table id="T_769b9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_769b9_level0_col0" class="col_heading level0 col0" >2015</th>
# ...
